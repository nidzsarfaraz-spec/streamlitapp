# %%
#career portal


def qualification(post,package,qual,exp):
    if (age>=35) and (qual==3 or qual==4) and (exp==4 or exp==5) and (gender==1 or gender==2) :
        job="You're Eligible for {post}, and your Package is Rs.{package}"
    elif (age>=25 and age<35) and (qual==3 or qual==4) and (exp==3 or exp==4) and (gender==1 or gender==2 or gender==3):
        job="You're Eligible  for {post},and your Package is Rs.{package}"
    elif(age>=18 and age<25)  and (qual==1 or qual==2) and (exp==1 or exp==2) and (gender==1 or gender==2 or gender==3):  
        job="You're Eligible  for {post},and your Package is Rs.{package}"
    else:
        job="No vacancy Available as per your details!"
    return job

def position():
    select=input("Select your domain: \n1.Engineeering \n2.Computer Science \n3.Admin \n4.Sales \n5.Marketing \n6.Any")
    if select=="1":
        print("Welcome to Engineering Positions!")
        if (age>=35) and (qual==3 or qual==4) and (exp==4 or exp==5) and (gender==1 or gender==2) :
            post="Senior Executive"
        elif (age>=25 and age<35) and (qual==3 or qual==4) and (exp==3 or exp==4) and (gender==1 or gender==2 or gender==3):
            post="Assistant Executive"
        elif(age>=18 and age<25)  and (qual==1 or qual==2) and (exp==1 or exp==2) and (gender==1 or gender==2 or gender==3):  
            post="Junior Executive"
        else:
            post="Clerk"
    elif select=="2":
        print("Welcome to Computer Science Positions!")
        if (age>=35) and (qual==3 or qual==4) and (exp==4 or exp==5) and (gender==1 or gender==2) :
            post="Senior Executive"
        elif (age>=25 and age<35) and (qual==3 or qual==4) and (exp==3 or exp==4) and (gender==1 or gender==2 or gender==3):
            post="Assistant Executive"
        elif(age>=18 and age<25)  and (qual==1 or qual==2) and (exp==1 or exp==2) and (gender==1 or gender==2 or gender==3):  
            post="Junior Executive"
        else:
            post="Clerk"  
    elif select=="3":
        print("Welcome to Admin Positions!")
        if (age>=35) and (qual==3 or qual==4) and (exp==4 or exp==5) and (gender==1 or gender==2) :
            post="Senior Executive"
        elif (age>=25 and age<35) and (qual==3 or qual==4) and (exp==3 or exp==4) and (gender==1 or gender==2 or gender==3):
            post="Assistant Executive"
        elif(age>=18 and age<25)  and (qual==1 or qual==2) and (exp==1 or exp==2) and (gender==1 or gender==2 or gender==3):  
            post="Junior Executive"
        else:
            post="Clerk"  
    elif select=="4":
        print("Welcome to Sales Positions!")
        if (age>=35) and (qual==3 or qual==4) and (exp==4 or exp==5) and (gender==1 or gender==2) :
            post="Senior Executive"
        elif (age>=25 and age<35) and (qual==3 or qual==4) and (exp==3 or exp==4) and (gender==1 or gender==2 or gender==3):
            post="Assistant Executive"
        elif(age>=18 and age<25)  and (qual==1 or qual==2) and (exp==1 or exp==2) and (gender==1 or gender==2 or gender==3):  
            post="Junior Executive"
        else:
            post="Clerk"  
    elif select=="5":
        print("Welcome to Marketing Positions!")
        if (age>=35) and (qual==3 or qual==4) and (exp==4 or exp==5) and (gender==1 or gender==2) :
            post="Senior Executive"
        elif (age>=25 and age<35) and (qual==3 or qual==4) and (exp==3 or exp==4) and (gender==1 or gender==2 or gender==3):
            post="Assistant Executive"
        elif(age>=18 and age<25)  and (qual==1 or qual==2) and (exp==1 or exp==2) and (gender==1 or gender==2 or gender==3):  
            post="Junior Executive"
        else:
            post="Clerk"  
    else:
        if (age>=35) and (qual==3 or qual==4) and (exp==4 or exp==5) and (gender==1 or gender==2) :
            post="Senior Executive"
        elif (age>=25 and age<35) and (qual==3 or qual==4) and (exp==3 or exp==4) and (gender==1 or gender==2 or gender==3):
            post="Assistant Executive"
        elif(age>=18 and age<25)  and (qual==1 or qual==2) and (exp==1 or exp==2) and (gender==1 or gender==2 or gender==3):  
            post="Junior Executive"
        else:
            post="Clerk"  
def packagenc_fu(qual,exp):    
    if (qual==3 or qual==4) and (exp==4 or exp==5):
        package="150000 and above"
    elif (qual==3 or qual==4) and (exp==3 or exp==4) and (gender==1 or gender==2 or gender==3):
        package="50000-120000"
    elif(qual==1 or qual==2) and (exp==1 or exp==2) and (gender==1 or gender==2 or gender==3):  
        package="30000-50000"
    else:
        package="20000-30000"
    return package


name=input("Enter your full name:")
yob=int(input("Enter your year of birth:"))
qual=int(input("let us know your highest qualification: \n1.Matric \n2.Intermediate \n3.Graduate \n4.Post-Grad"))
exp=int(input("Year of Experience you have? \n1.Fresh \n2.1-3 \n3.3-6 \n4.6-10 \n5.10+"))
gender=input("Gender? \n1.Male \n2.Female \n3.Rather not to say")


package=package_func (qual,exp)
post=position(package,qual,exp,age,gender)
qualification(post,package,qual,exp,age,gender)
# Out:
#   Cell In[7], line 36
#     job="Clerk"
#     ^
# IndentationError: expected an indented block after 'else' statement on line 35
