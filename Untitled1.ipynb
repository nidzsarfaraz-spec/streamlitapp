# %%
import currency as c
# Out:
# Welcome to currency exchange
# Which country you want your pkr to be exchanged? :
# 1.PKR to USD
# 2.PKR to Dinar
# 3.PKR to RIYAL
# 4.PKR to DIRHAM
# 5.PKR to POUND 1
# Enter an Amount you want to convert from pkr: 50000
# Here is your Currency in USD 180.0

# %%
1
