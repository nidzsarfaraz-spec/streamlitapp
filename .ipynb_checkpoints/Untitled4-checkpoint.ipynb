# %%
def qualification(position,package,age,qual,Exp,gender):
    if (age>=35) and (qual==3 or qual==4) and (Exp==4 or Exp==5) and (gender==1 or gender==2):
        job="You are Eligible for {post}, and your Package is {package}"
    elif (age>=25 and age<35) and (qual==3 or qual==4) and (Exp==3 or Exp==4) and (gender==1 or gender==2):
        job="You are Eligible for {post}, and your Package is {package}"
    elif (age>=18 and age<25) and (qual==1 or qual==2 or qual==3) and (Exp==1 or Exp==2) and (gender==1 or gender==2):
        job="You are Eligible for {post}, and your Package is {package}"
    else:
        job="No Vacancy is Available as per your details"
    return job

def position(package,qual,Exp,age,gender):
    select= input("Select you interest Domain: \n1) Enginering \n2) Computer Science \n3) Admin \n4) Sales \n5) Marketing \n6) Any")
    if select=="1":
        print(f"Welcome to Enigeenering Position")
        if (age>=35) and (qual==3 or qual==4) and (Exp==4 or Exp==5) and (gender==1 or gender==2):
            post="Senoir Executive"
        elif (age>=25 and age<35) and (qual==3 or qual==4) and (Exp==3 or Exp==4) and (gender==1 or gender==2):
            post="Assistant Executive"
        elif (age>=18 and age<25) and (qual==1 or qual==2 or qual==3) and (Exp==1 or Exp==2) and (gender==1 or gender==2):
            post="Junoir Executive"
        else:
            post="Tranie Engineer"
    elif select=="2":
        print(f"Welcome to CS Position")
        if (age>=35) and (qual==3 or qual==4) and (Exp==4 or Exp==5) and (gender==1 or gender==2):
            post="Senoir Executive"
        elif (age>=25 and age<35) and (qual==3 or qual==4) and (Exp==3 or Exp==4) and (gender==1 or gender==2):
            post="Assistant Executive"
        elif (age>=18 and age<25) and (qual==1 or qual==2 or qual==3) and (Exp==1 or Exp==2) and (gender==1 or gender==2):
            post="Junoir Executive"
        else:
            post="Tranie CS"
    elif select=="3":
        print(f"Welcome to Admin Position")
        if (age>=35) and (qual==3 or qual==4) and (Exp==4 or Exp==5) and (gender==1 or gender==2):
            post="Senoir Executive"
        elif (age>=25 and age<35) and (qual==3 or qual==4) and (Exp==3 or Exp==4) and (gender==1 or gender==2):
            post="Assistant Executive"
        elif (age>=18 and age<25) and (qual==1 or qual==2 or qual==3) and (Exp==1 or Exp==2) and (gender==1 or gender==2):
            post="Junoir Executive"
        else:
            post="Tranie Admin Officer"
    elif select=="4":
        print(f"Welcome to Sales Position")
        if (age>=35) and (qual==3 or qual==4) and (Exp==4 or Exp==5) and (gender==1 or gender==2):
            post="Senoir Executive"
        elif (age>=25 and age<35) and (qual==3 or qual==4) and (Exp==3 or Exp==4) and (gender==1 or gender==2):
            post="Assistant Executive"
        elif (age>=18 and age<25) and (qual==1 or qual==2 or qual==3) and (Exp==1 or Exp==2) and (gender==1 or gender==2):
            post="Junoir Executive"
        else:
            post="Tranie Sales"
    elif select=="5":
        print(f"Welcome to Marketing Position")
        if (age>=35) and (qual==3 or qual==4) and (Exp==4 or Exp==5) and (gender==1 or gender==2):
            post="Senoir Executive"
        elif (age>=25 and age<35) and (qual==3 or qual==4) and (Exp==3 or Exp==4) and (gender==1 or gender==2):
            post="Assistant Executive"
        elif (age>=18 and age<25) and (qual==1 or qual==2 or qual==3) and (Exp==1 or Exp==2) and (gender==1 or gender==2):
            post="Junoir Executive"
        else:
            post="Tranie Marketing"
    else:
        print(f"Welcome to Any Position")
        if (age>=35) and (qual==3 or qual==4) and (Exp==4 or Exp==5) and (gender==1 or gender==2):
            post="Senoir Executive"
        elif (age>=25 and age<35) and (qual==3 or qual==4) and (Exp==3 or Exp==4) and (gender==1 or gender==2):
            post="Assistant Executive"
        elif (age>=18 and age<25) and (qual==1 or qual==2 or qual==3) and (Exp==1 or Exp==2) and (gender==1 or gender==2):
            post="Junoir Executive"
        else:
            post="Tranie Position"
        return post

def package(qual,Exp):
        if (qual==3 or qual==4) and (Exp==4 or Exp==5):
            pack="1 Lack Rupees and Above"
        elif (age>=25 and age<35) and (qual==3 or qual==4) and (Exp==3 or Exp==4) and (gender==1 or gender==2):
            pack="50K Rupees"
        elif (age>=18 and age<25) and (qual==1 or qual==2 or qual==3) and (Exp==1 or Exp==2) and (gender==1 or gender==2):
            pack="25K Rupees"
        else:
            pack="NO Salary"
        return pack

name=input("Enter your full name:")
yob=int(input("Enter your year of birth:"))
qual=int(input("Let us know your highest qualification : \n1. Matric \n2. Intermediate \n3. Graduate \n4. Post_Grad"))
exp=int(input("How much experiance you posses : \n1. Fresh \n2. 0-1 \n3. 1-3 \n4. 3-5 \n5. 5-10 \n6. 10+"))
gender=int(input("Enter your Gender: \n1. Male \n2. Female \n3. Pata nahi "))
age=2026-yob

position(package,qual,exp,age,gender)
qualification (postion,package,qual,exp,age,gender)
package_func (qual,exp)
# Out:
# Enter your full name: Nida Ahsan
# Enter your year of birth: 1991
# Let us know your highest qualification :
# 1. Matric
# 2. Intermediate
# 3. Graduate
# 4. Post_Grad
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 89
#      87 name=input("Enter your full name:")
#      88 yob=int(input("Enter your year of birth:"))
# ---> 89 qual=int(input("Let us know your highest qualification : \n1. Matric \n2. Intermediate \n3. Graduate \n4. Post_Grad"))
#      90 exp=int(input("How much experiance you posses : \n1. Fresh \n2. 0-1 \n3. 1-3 \n4. 3-5 \n5. 5-10 \n6. 10+"))
#      91 gender=int(input("Enter your Gender: \n1. Male \n2. Female \n3. Pata nahi "))
#
# ValueError: invalid literal for int() with base 10: ''
