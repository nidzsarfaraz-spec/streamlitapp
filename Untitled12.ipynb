# %%
#list fundamentals

rafay=["rafay",123,9.0]  #list can store any data type as an element

# %%
rafay
# Out:
# ['rafay', 123, 9.0]

# %%
#list calling
rafay[0]
# Out:
# 'rafay'

# %%
type(rafay[0])
# Out:
# str

# %%
rafay
# Out:
# ['rafay', 123, 9.0]

# %%
rafay[-1]   #to call value fromright to left we use (-1)
# Out:
# 9.0

# %%
rafay[0]="sir babar"  #update

# %%
rafay
# Out:
# ['sir babar', 123, 9.0]

# %%
rafay.append("sir jahanzaib")  #method to add element to add element at last of the list

# %% [raw]
# rafay

# %%
rafay.remove("sir babar")

# %%
rafay
# Out:
# [123, 9.0, 'sir jahanzaib']

# %%
rafay.insert(1,"sir babar")

# %%
rafay
# Out:
# [123, 'sir babar', 9.0, 'sir jahanzaib']

# %%
rafay.insert(1,50)

# %%
rafay
# Out:
# [123, 50, 'sir babar', 9.0, 'sir jahanzaib']

# %%
rafay.count("sir jahanzaib")
# Out:
# 1

# %%
rafay.clear()

# %%
rafay
# Out:
# []

# %%
rafay1=[123, 50, 'sir babar', 9.0, 'sir jahanzaib']

# %% [raw]
# rafay2=rafay1

# %%
rafay2
# Out:
# []

# %%
#sum, min max, len,

# %%
#list comprehension- khaali list ko fill karna automatically(kum efforts to create list)
