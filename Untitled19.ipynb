# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.1'

# %%
data = {
    'name':["rafay","kirpal","kewal","waqas","umair","nida"],
    'age' :[29,22,31,39,43,32],
    'salary':[1000,3000,4000,5000,6000,7000],
    'email':["rafay@gmail.com","kirpal@gmail.com","kewal@gmail.com","waqas@gmail.com","umair@gmail.com","nida@gmail.com"]
}

# %%
data
# Out:
# {'name': ['rafay', 'kirpal', 'kewal', 'waqas', 'umair', 'nida'],
#  'age': [29, 22, 31, 39, 43, 32],
#  'salary': [1000, 3000, 4000, 5000, 6000, 7000],
#  'email': ['rafay@gmail.com',
#   'kirpal@gmail.com',
#   'kewal@gmail.com',
#   'waqas@gmail.com',
#   'umair@gmail.com',
#   'nida@gmail.com']}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      name  age  salary             email
# 0   rafay   29    1000   rafay@gmail.com
# 1  kirpal   22    3000  kirpal@gmail.com
# 2   kewal   31    4000   kewal@gmail.com
# 3   waqas   39    5000   waqas@gmail.com
# 4   umair   43    6000   umair@gmail.com
# 5    nida   32    7000    nida@gmail.com

# %%
df["Team"]=['Admin','CEO','Operations','CTO','Founder','Director']

# %%
df
# Out:
#      name  age  salary             email        Team
# 0   rafay   29    1000   rafay@gmail.com       Admin
# 1  kirpal   22    3000  kirpal@gmail.com         CEO
# 2   kewal   31    4000   kewal@gmail.com  Operations
# 3   waqas   39    5000   waqas@gmail.com         CTO
# 4   umair   43    6000   umair@gmail.com     Founder
# 5    nida   32    7000    nida@gmail.com    Director

# %%
df.loc[len(df)]=['Ali',24,8000,"ali@gmail.com","Assistant"]

# %%
df
# Out:
#      name  age  salary             email        Team
# 0   rafay   29    1000   rafay@gmail.com       Admin
# 1  kirpal   22    3000  kirpal@gmail.com         CEO
# 2   kewal   31    4000   kewal@gmail.com  Operations
# 3   waqas   39    5000   waqas@gmail.com         CTO
# 4   umair   43    6000   umair@gmail.com     Founder
# 5    nida   32    7000    nida@gmail.com    Director
# 6     Ali   24    8000     ali@gmail.com   Assistant

# %%
df.style.set_properties(**{'text-align':'center'})
# Out:
# <style type="text/css">
# #T_76106_row0_col0, #T_76106_row0_col1, #T_76106_row0_col2, #T_76106_row0_col3, #T_76106_row0_col4, #T_76106_row1_col0, #T_76106_row1_col1, #T_76106_row1_col2, #T_76106_row1_col3, #T_76106_row1_col4, #T_76106_row2_col0, #T_76106_row2_col1, #T_76106_row2_col2, #T_76106_row2_col3, #T_76106_row2_col4, #T_76106_row3_col0, #T_76106_row3_col1, #T_76106_row3_col2, #T_76106_row3_col3, #T_76106_row3_col4, #T_76106_row4_col0, #T_76106_row4_col1, #T_76106_row4_col2, #T_76106_row4_col3, #T_76106_row4_col4, #T_76106_row5_col0, #T_76106_row5_col1, #T_76106_row5_col2, #T_76106_row5_col3, #T_76106_row5_col4, #T_76106_row6_col0, #T_76106_row6_col1, #T_76106_row6_col2, #T_76106_row6_col3, #T_76106_row6_col4 {
#   text-align: center;
# }
# </style>
# <table id="T_76106">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76106_level0_col0" class="col_heading level0 col0" >name</th>
# ...

# %%
df['name']=df["name"].astype(str).str.capitalize()

# %%
df2=df.groupby("Team")["salary"].sum()

# %%
import matplotlib.pyplot as plt

# %%
df2.plot.pie(autopct='%1.2f')
# Out:
# <Axes: >
