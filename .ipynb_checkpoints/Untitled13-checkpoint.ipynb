# %%
#dictionaries in python- Data Structure Fundamentals

# %%
#nida={key:[123,1234],key1:1234, key2:12345}  #dictionaries represented through curly brackets

#1ST Method to create dictionary
cohort={'course':'AI','Trainer':'Rafay','Level':'Advanced'}

print (cohort['course'])
# Out:
# AI

# %%
#2nd Method to create dictionary
person2=dict([('name','Rafay'),('age','29'),('city','karachi')])

# %%
person2
# Out:
# {'name': 'Rafay', 'age': '29', 'city': 'karachi'}

# %%
#3rd method to create dictionary by using constructor

person3=dict(name="nida",age=32,city="Karachi")

# %%
person3
# Out:
# {'name': 'nida', 'age': 32, 'city': 'Karachi'}

# %%
person3.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
person3.values()
# Out:
# dict_values(['nida', 32, 'Karachi'])

# %%
person3.items()
# Out:
# dict_items([('name', 'nida'), ('age', 32), ('city', 'Karachi')])

# %%
#to add in dictionary

person3["email"] = "nidaahsan20@gmail.com"

# %%
person3
# Out:
# {'name': 'nida',
#  'age': 32,
#  'city': 'Karachi',
#  'email': 'nidaahsan20@gmail.com'}

# %%
del person3['email']

# %%
person3
# Out:
# {'name': 'nida', 'age': 32, 'city': 'Karachi'}

# %%
person3.pop('city')
# Out:
# 'Karachi'

# %%
person3
# Out:
# {'name': 'nida', 'age': 32}

# %%
for values in person3.values():
    print (values)
# Out:
# nida
# 32

# %%
for keys in person3:
    print(keys)
# Out:
# name
# age

# %%
for i in person3.values:
    print(f"type of {i})
# Out:
#   Cell In[41], line 2
#     print(f"type of {i})
#           ^
# SyntaxError: unterminated f-string literal (detected at line 2)
