# %%
#school Management
#using nested dictionary

school_database=[]

# %%
school_database={a:('name':['Ali','Alia','Akbar','Basit','Bilal','Dania','Durefishan']),('age':[12,13,10,15,]('class':[7,8,5,4 'o-level'],['age':9,8
# Out:
#   Cell In[11], line 1
#     school_database={a:['name':'Ali','age':12,'class':7],['name':'Alia','age':13,'class':8],['name':'Akbar','age':12,'class':7],['name':Basit','age':10,'class':5],['name':'Bilal','age':15,'class''o-level'],['name':'Dania','age':9,'class':4],['name':'Durefishan','age':8,'class':8]}
#                                                                                                                                                                                                                                                                                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
school_database[a]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 school_database[a]
#
# NameError: name 'a' is not defined
