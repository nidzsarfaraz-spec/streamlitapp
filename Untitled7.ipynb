# %%
log=[]
def admin():
    while True:
        no=int(input("Enter a number of Students you want to create:"))
        for i in range(no):
            username=input(f"Enter a user {i+1} name:").lower()
            password=input(f"Enter a {i+1} Password:")
            log.append([username,password])
        check=input("What you want to check: \n1:Count of Students \n2:want to search any Student? \n3:Wnat to remove any Student? \n4:want to add any Student?")
        if check=="1":
            print(f"Total number of Student are: {len(log)}")
            break
        elif check=="2":
            lst=[]
            for i in range(len(log)-1):
                lst.append(log[i][0])
            checkk2=input("Enter a name of Student you want to search:").lower()
            count=lst.count(check2)
            if count>0:
                print("user exist!")
                break
            else:
                print("user does not exist!")
                break
        elif check=="3":
            lst=[]
            for i in range(len(log)):
                lst.append(log[i][0])
            check2=input("Enter a name of user you want to remove?").lower()
            var=lst.index(check2)
            print(log.pop(var))
            print(f"updated User details are :{log}")

        break

# %%
admin()
# Out:
# Enter a number of user you want to create: 3
# Enter a user 1 name: UMER
# Enter a 1 Password: 123
# Enter a user 2 name: ALI
# Enter a 2 Password: 123
# Enter a user 3 name: NIDA
# Enter a 3 Password: 123
# What you want to check:
# 1:CCount of users
# 2:want to search any user?
# 3:Wnat to remove any user?
# 4:want to add any user? 3
# Enter a name of user you want to remove? NIDA
# ['nida', '123']
# updated User details are :[['umer', '123'], ['ali', '123']]

# %%
course=[]
def courses():
    while True:
        num=int(input("Enter a number of courses you want to add?:"))
        if num>=6:
            print("You have exceeded the limit of courses:!")
            break
        else:
            all=[]
            for i in range (1,num+1):
                name=input("Enter a name of course you want to add:")
                all.append(name)
                print(all)
            course.append([all])
            print(course)
        

        rerun=input("do you want to add courses for further students? (yes or no):").lower()
        if rerun=="yes":
            continue
        else:
            
            break

# %%
courses()
# Out:
# Enter a number of courses you want to add?: 2
# Enter a name of course you want to add: physics
# ['physics']
# Enter a name of course you want to add: chemistry
# ['physics', 'chemistry']
# [[['math', 'english', 'physics', 'urdu', 'islamiat']], [['physics', 'chemistry']]]
# do you want to add courses for further students? (yes or no): yes
# Enter a number of courses you want to add?: 3
# Enter a name of course you want to add: urdu
# ['urdu']
# Enter a name of course you want to add: english
# ['urdu', 'english']
# Enter a name of course you want to add: math
# ['urdu', 'english', 'math']
# [[['math', 'english', 'physics', 'urdu', 'islamiat']], [['physics', 'chemistry']], [['urdu', 'english', 'math']]]
