# %%
rafay=["hello",123,1.2,{1:1}]

rafay.append("rice")

# %%
rafay
# Out:
# ['hello', 123, 1.2, {1: 1}, 'rice']

# %%
rafay.append("taha")

# %%
rafay
# Out:
# ['hello', 123, 1.2, {1: 1}, 'rice', 'taha']

# %%
rafay.append("taha")

# %%
rafay
# Out:
# ['hello', 123, 1.2, {1: 1}, 'rice', 'taha', 'taha', 'taha']

# %%
rafay
# Out:
# ['hello', 123, 1.2, {1: 1}, 'rice', 'taha', 'taha', 'taha']

# %%
rafay.count("hello")
